# %% [markdown]
# ## 0. Prerequisites
# You need:
# - VSCode
# - Node.js + npm
# - (Later) Git + GitHub
# - (Later) Backend runtime (Node/Express) and a database (we'll start simple, then upgrade)

# %%
node -v
npm -v

# %% [markdown]
# ## Step 1: Create frontend project with Vite
# `npm create vite@latest frontend`: uses npm to download and run Vite’s official scaffolding tool to create a new React frontend project template in a folder named `frontend`.

# %%
npm create vite@latest frontend
